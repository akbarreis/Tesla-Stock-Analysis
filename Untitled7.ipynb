# %%
import pandas as pd

# %% [markdown]
# In the graph that you will see below, you will be provided with all the data of Tesla, all the characteristics of their activities

# %%
df = pd.read_csv('tesla02.csv')

# %%
df
# Out:
#                   Column1           Column2           Column3  \
# 0        Number of colown        30.06.2021        31.03.2021
# 1            Gross profit   2 884 000 000 $   2 215 000 000 $
# 2              Cost price   9 074 000 000 $   8 174 000 000 $
# 3       Operating revenue  11 958 000 000 $  10 389 000 000 $
# 4        Operating income                 0                 0
# 5              Net income   1 312 000 000 $     594 000 000 $
# 6            R&D expenses   1 142 000 000 $     438 000 000 $
# 7      Operating expenses     576 000 000 $     666 000 000 $
# 8          Current assets  10 646 000 000 $   9 795 000 000 $
# 9            Total assets  24 693 000 000 $  24 705 000 000 $
# 10           Current cash  55 146 000 000 $  52 972 000 000 $
# 11           Current debt  16 229 000 000 $  17 141 000 000 $
# 12  Total amount of funds                 0                 0
# 13             Total debt                 0                 0
# ...
